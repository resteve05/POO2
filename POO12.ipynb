# %% [markdown]
# #Creación de una base de datos
# JSON es java script object notation
# API es application programming interface

# %%
base = {"Rodrigo":[1,0,4,2,3], "Pedro": [0,1,6,8,9], "Majo":[7,2,1,3,10], "Ana": [3,4,7,1,9], "Pablo":[10,4,7,2,9]}
base #hacer y escribir datos con características
# Out:
# {'Rodrigo': [1, 0, 4, 2, 3],
#  'Pedro': [0, 1, 6, 8, 9],
#  'Majo': [7, 2, 1, 3, 10],
#  'Ana': [3, 4, 7, 1, 9],
#  'Pablo': [10, 4, 7, 2, 9]}

# %%
type(base) #Para saber que tipo de texto es. Dict es diccionario
# Out:
# dict

# %%
import pandas as pd #pandas es panel data (panel like excel)

tabla = pd.DataFrame(base)
tabla
# Out:
#    Rodrigo  Pedro  Majo  Ana  Pablo
# 0        1      0     7    3     10
# 1        0      1     2    4      4
# 2        4      6     1    7      7
# 3        2      8     3    1      2
# 4        3      9    10    9      9

# %% [markdown]
# #Que es un API
# ##Interfaz que nos ayuda a tomar e interpretar datos de la red
# APIs are mechanisms that enable two software components to communicate with each other using a set of definitions and protocols. For example, the weather bureau’s software system contains daily weather data. The weather app on your phone “talks” to this system via APIs and shows you daily weather updates on your phone.
# API architecture is usually explained in terms of client and server. The application sending the request is called the client, and the application sending the response is called the server. So in the weather example, the bureau’s weather database is the server, and the mobile app is the client.
#
# There are four different ways that APIs can work depending on when and why they were created.
#
# SOAP APIs
# These APIs use Simple Object Access Protocol. Client and server exchange messages using XML. This is a less flexible API that was more popular in the past.
#
# RPC APIs
# These APIs are called Remote Procedure Calls. The client completes a function (or procedure) on the server, and the server sends the output back to the client.
#
# Websocket APIs
# Websocket API is another modern web API development that uses JSON objects to pass data. A WebSocket API supports two-way communication between client apps and the server. The server can send callback messages to connected clients, making it more efficient than REST API.
#
# REST APIs
# These are the most popular and flexible APIs found on the web today. The client sends requests to the server as data. The server uses this client input to start internal functions and returns output data back to the client. Let’s look at REST APIs in more detail below.
#
# ---
# Fuente: [API](https://aws.amazon.com/what-is/api/#:~:text=API%20stands%20for%20Application%20Programming,other%20using%20requests%20and%20responses.)

# %%
import yfinance as yf #Importa de yahoo finance
ticker = "AAPL" #escoger el ticker
Apple = yf.download(ticker, start = "2020-01-01", end= "2024-01-01") #Descargar ese ticker en cierta fecha
Apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.059425
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.349144
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.925621
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.582657
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.750244
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Date
# ...
